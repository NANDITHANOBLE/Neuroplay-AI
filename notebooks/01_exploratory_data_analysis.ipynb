# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from neuroplay.preprocessing.loader import load_moves_dataframe\n",
    "from neuroplay.eda.visualizations import (\n",
    "    plot_move_distribution, plot_win_rate_by_persona,\n",
    "    plot_transition_heatmap, plot_drift_visualization\n",
    ")\n",
    "from neuroplay.eda.complexity import lempel_ziv_complexity"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df = load_moves_dataframe()\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.groupby(\"model_used\").size()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plot_move_distribution(df)\n",
    "plot_win_rate_by_persona(df)\n",
    "for persona in df[\"model_used\"].unique():\n",
    "    plot_transition_heatmap(df, persona)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "drift_rows = df[df[\"model_used\"] == \"synthetic_drift\"]\n",
    "drift_match_id = drift_rows[\"match_id\"].iloc[0]\n",
    "plot_drift_visualization(df, drift_match_id)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "for persona, group in df.groupby(\"model_used\"):\n",
    "    sample_match = group[\"match_id\"].iloc[0]\n",
    "    moves = group[group[\"match_id\"] == sample_match][\"player_move\"].tolist()\n",
    "    print(persona, \"LZ complexity:\", lempel_ziv_complexity(moves))"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11.9"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
